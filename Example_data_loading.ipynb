# %%
from curated_data import data_dict
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from raw_data import data_dict
#
# ModuleNotFoundError: No module named 'raw_data'
